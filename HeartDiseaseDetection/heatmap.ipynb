# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the CSV file
data = pd.read_csv('./heart.csv')

# Compute the correlation matrix
correlation_matrix = data.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    cbar=True
)
plt.title("Correlation Heatmap")
plt.show()
# Out:
#      <input type="file" id="files-05a3c825-6229-438d-8ff9-d4656704e867" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05a3c825-6229-438d-8ff9-d4656704e867">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Upload file
uploaded = files.upload()

# Load CSV file
data = pd.read_csv('./heart.csv')

# Check for and drop missing values
data = data.dropna()

# Normalize numerical features
scaler = MinMaxScaler()
numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns
data[numeric_columns] = scaler.fit_transform(data[numeric_columns])

# Feature Engineering
data['age_cholesterol'] = data['age'] * data['chol']
data['thalach_slope'] = data['thalach'] * data['slope']

# Compute correlations with target
correlations = data.corr()['target'].sort_values(ascending=False)
print("Correlations with target:\n", correlations)

# Filter for highly correlated features
high_corr_features = correlations[abs(correlations) > 0.2].index
correlation_matrix = data[high_corr_features].corr()

# Plot enhanced heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    cbar=True,
    linewidths=0.5,
)
plt.title("Enhanced Correlation Heatmap")
plt.show()
# Out:
#      <input type="file" id="files-f007b1ec-c20b-40e2-9f80-5c9de59e8062" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f007b1ec-c20b-40e2-9f80-5c9de59e8062">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !git config --global user.email "twoodc1@lsu.edu"
# !git config --global user.name "thomasw33"
# !git clone https://github.com/roest1/ML_Proj.git
# !ls
# Out:
# Cloning into 'ML_Proj'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 47 (delta 9), reused 45 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (47/47), 169.54 KiB | 2.02 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# ML_Proj  sample_data

# %%
# !ls /content
from google.colab import files
uploaded = files.upload()
# Out:
# ML_Proj  sample_data
#      <input type="file" id="files-6b81ef7b-84da-4406-8112-3268b94d4475" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b81ef7b-84da-4406-8112-3268b94d4475">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
